# %%
import os
import glob as glob
import matplotlib.pyplot as plt
import cv2
import requests

# %% [markdown]
# if not os.path.exists('yolov5'):
#     !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5/
# !pip install -r requirements.txt

# %%
import torch
import cv2
import time
model = torch.hub.load('yolov5/','custom', path='yolov5/best.pt', source='local')  # local repo
model.conf = 0.7
# Out:
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.11.7 torch-2.2.2+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
# Adding AutoShape...

# %%
img=cv2.imread('yolov5/inference_images/2.jpeg')

# %%
st=time.time()
result=model(img)
print(time.time()-st)
# Out:
# 0.31415486335754395

# %%
result=model(img).pandas().xyxy[0]

# %%
result
# Out:
#          xmin        ymin         xmax        ymax  confidence  class     name
# 0  942.150757  841.759827  1084.521362  989.292236    0.898848      0  qr_code

# %%
from pyzbar.pyzbar import decode
from PIL import Image
from pyzbar.pyzbar import decode

# %%
decode(Image.fromarray(img[int(result.ymin[0]):int(result.ymax[0]),int(result.xmin[0]):int(result.xmax[0])]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 decode(Image.fromarray(img[int(result.ymin[0]):int(result.ymax[0]),int(result.xmin[0]):int(result.xmax[0])]))
#
# NameError: name 'img' is not defined

# %%
from pyzbar.pyzbar import decode
from PIL import Image
#decode(Image.open('yolov5/inference_images/2.jpeg'))[0].data.decode()

# %%
decoded_list=decode(Image.open('0.jpeg'))
for box_i in range(len(decoded_list)):
    print(decoded_list[box_i])
# Out:
# Decoded(data=b'https://qec.qu.edu.sa/content/news/2019', type='QRCODE', rect=Rect(left=151, top=1072, width=95, height=95), polygon=[Point(x=151, y=1072), Point(x=151, y=1167), Point(x=245, y=1166), Point(x=246, y=1072)], quality=1, orientation='UP')
# Decoded(data=b'https://me-qr.com/GWUohYLb', type='QRCODE', rect=Rect(left=524, top=656, width=94, height=95), polygon=[Point(x=524, y=656), Point(x=524, y=751), Point(x=618, y=750), Point(x=618, y=656)], quality=1, orientation='LEFT')

# %%
decoded=

# %%
decoded[1][0]
# Out:
# b'https://me-qr.com/GWUohYLb'

# %%
pos_x,pos_y=(decoded.polygon[1])

# %%
import cv2
import numpy as np

# Load an image
image_path = '11.jpeg'
image = cv2.imread(image_path)

# Specify the center and radius of the circle
center_coordinates = (pos_x,pos_y+decoded.rect.height//4)  # (x, y) coordinate
radius = 20

# Define the color of the circle in BGR format (blue in this case)
color = (255, 0, 0)

# Draw the circle on the image
image_with_circle = cv2.circle(image, center_coordinates, radius, color, thickness=2)

# Display the image with the circle
cv2.imshow('Image with Circle', image_with_circle)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ...
# QObject::moveToThread: Current thread (0x2bf7720) is not the object's thread (0x2cd8960).
# Cannot move to target thread (0x2bf7720)
#
# QObject::moveToThread: Current thread (0x2bf7720) is not the object's thread (0x2cd8960).
# Cannot move to target thread (0x2bf7720)
#
# QObject::moveToThread: Current thread (0x2bf7720) is not the object's thread (0x2cd8960).
# Cannot move to target thread (0x2bf7720)
#
# QObject::moveToThread: Current thread (0x2bf7720) is not the object's thread (0x2cd8960).
# Cannot move to target thread (0x2bf7720)
#
# QObject::moveToThread: Current thread (0x2bf7720) is not the object's thread (0x2cd8960).
# Cannot move to target thread (0x2bf7720)
#
# QObject::moveToThread: Current thread (0x2bf7720) is not the object's thread (0x2cd8960).
# Cannot move to target thread (0x2bf7720)
#
# QObject::moveToThread: Current thread (0x2bf7720) is not the object's thread (0x2cd8960).
# Cannot move to target thread (0x2bf7720)
#
# ...

# %%
12
